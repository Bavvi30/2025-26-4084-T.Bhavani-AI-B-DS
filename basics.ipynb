# %% [markdown]
# <a href="https://colab.research.google.com/github/Bavvi30/2025-26-4084-T.Bhavani-AI-B-DS/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 27
b = 30
print(a)
print(b)
# Out:
# 27
# 30
